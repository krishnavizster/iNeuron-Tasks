# %% [markdown]
# TASK 2 IN PANDAS 5/3/2022
# For titanic datset :https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
# 1 . Find out how many male and female passenger was onboarded .
# 2. how many survived we have .
# 3. how many casuality we have
# 4 . what is name of a person who is the eldest one .
# 5 . how many passenger do we have in first , second and third class
# 6. how many person we have whose name starts with "s"
# 7. try to create a new column which is a summation  of "SibSp" and "parch"
# 8 . how many person do we have below age of 25 .
# 9 . how many person died whose age was less then 40
# 10 . from a  cabin column seperate text and numeric value .
#
# For Bank Marketing Data Set ataset link - https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
# 1 . how many campaign available in this dataset .
# 2 . how many users do we have with housing and personal loan .
# 3. how many person do we have whose age is 60+ .
# 4 . in which month we have trageted most of the customer .
# 5 . which mode of call is giving you more result
# 6 . how many enterpeures do we have in this list
# 7 . how many customers do we have with negative balance
# 8. prepare a group of data based on education level .

# %%
import pandas as pd

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#1.Find out how many male and female passenger was onboarded.
df["Sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
genders = {"male": 0, "female": 1}
data = [df]
df['Sex'].value_counts()
# Out:
# 0    577
# 1    314
# Name: Sex, dtype: int64

# %%
#2. how many survived we have .

# %%
df["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#3. how many casuality we have

# %%
df["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#4 . what is name of a person who is the eldest one .

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
max(df["Age"])
# Out:
# 80.0

# %%
df[df["Age"]==max(df["Age"])]
# Out:
#      PassengerId  Survived  Pclass                                  Name  Sex  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson    0
#
#       Age  SibSp  Parch Ticket  Fare Cabin Embarked
# 630  80.0      0      0  27042  30.0   A23        S

# %%
df[df["Age"]==max(df["Age"])]["Name"]
# Out:
# 630    Barkworth, Mr. Algernon Henry Wilson
# Name: Name, dtype: object

# %%
#5 . how many passenger do we have in first , second and third class

# %%
df["Pclass"]
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#6. how many person we have whose name starts with "s"

# %%
df["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
names_s  = df["Name"].str.startswith('s', na = False)
df[names_s]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, summation]
# Index: []

# %%
df["Name"].value_counts("s")
# Out:
# Scanlan, Mr. James                           0.001122
# Gustafsson, Mr. Karl Gideon                  0.001122
# Hansen, Mr. Henrik Juul                      0.001122
# Dean, Master. Bertram Vere                   0.001122
# McEvoy, Mr. Michael                          0.001122
#                                                ...
# Sirayanian, Mr. Orsen                        0.001122
# Andersson, Master. Sigvard Harald Elias      0.001122
# O'Connell, Mr. Patrick D                     0.001122
# Carter, Mrs. William Ernest (Lucile Polk)    0.001122
# Peter, Miss. Anna                            0.001122
# Name: Name, Length: 891, dtype: float64

# %%
#7. try to create a new column which is a summation  of "SibSp" and "parch"

# %%
sum_column = df["SibSp"] + df["Parch"]
df["summation"] = sum_column

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# 886                              Montvila, Rev. Juozas    0  27.0      0
# 887                       Graham, Miss. Margaret Edith    1  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"    1   NaN      1
# 889                              Behr, Mr. Karl Howell    0  26.0      0
# 890                                Dooley, Mr. Patrick    0  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  summation
# 0        0         A/5 21171   7.2500   NaN        S          1
# 1        0          PC 17599  71.2833   C85        C          1
# 2        0  STON/O2. 3101282   7.9250   NaN        S          0
# 3        0            113803  53.1000  C123        S          1
# 4        0            373450   8.0500   NaN        S          0
# ..     ...               ...      ...   ...      ...        ...
# 886      0            211536  13.0000   NaN        S          0
# 887      0            112053  30.0000   B42        S          0
# 888      2        W./C. 6607  23.4500   NaN        S          3
# 889      0            111369  30.0000  C148        C          0
# 890      0            370376   7.7500   NaN        Q          0
#
# [891 rows x 13 columns]

# %%
#8 . how many person do we have below age of 25 .

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df[df["Age"]==25]
# Out:
#      PassengerId  Survived  Pclass  \
# 75            76         0       3
# 134          135         0       2
# 246          247         0       3
# 267          268         1       3
# 271          272         1       3
# 343          344         0       2
# 353          354         0       3
# 370          371         1       1
# 442          443         0       3
# 484          485         1       1
# 498          499         0       1
# 580          581         1       2
# 666          667         0       2
# 685          686         0       2
# 693          694         0       3
# 703          704         0       3
# 728          729         0       2
# 729          730         0       3
# 784          785         0       3
# 785          786         0       3
# 794          795         0       3
# 880          881         1       2
# 884          885         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 75                           Moen, Mr. Sigurd Hansen    0  25.0      0      0
# 134                   Sobey, Mr. Samuel James Hayden    0  25.0      0      0
# 246            Lindahl, Miss. Agda Thorilda Viktoria    1  25.0      0      0
# 267                         Persson, Mr. Ernst Ulrik    0  25.0      1      0
# 271                     Tornquist, Mr. William Henry    0  25.0      0      0
# 343       Sedgwick, Mr. Charles Frederick Waddington    0  25.0      0      0
# 353                        Arnold-Franchi, Mr. Josef    0  25.0      1      0
# 370                      Harder, Mr. George Achilles    0  25.0      1      0
# 442                        Petterson, Mr. Johan Emil    0  25.0      1      0
# 484                          Bishop, Mr. Dickinson H    0  25.0      1      0
# 498  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)    1  25.0      1      2
# 580                      Christy, Miss. Julie Rachel    1  25.0      1      1
# 666                      Butler, Mr. Reginald Fenton    0  25.0      0      0
# 685           Laroche, Mr. Joseph Philippe Lemercier    0  25.0      1      2
# 693                                 Saad, Mr. Khalil    0  25.0      0      0
# 703                            Gallagher, Mr. Martin    0  25.0      0      0
# 728                  Bryhl, Mr. Kurt Arnold Gottfrid    0  25.0      1      0
# 729                    Ilmakangas, Miss. Pieta Sofia    1  25.0      1      0
# 784                                 Ali, Mr. William    0  25.0      0      0
# 785               Harmer, Mr. Abraham (David Lishin)    0  25.0      0      0
# 794                            Dantcheff, Mr. Ristiu    0  25.0      0      0
# 880     Shelley, Mrs. William (Imanita Parrish Hall)    1  25.0      0      1
# 884                           Sutehall, Mr. Henry Jr    0  25.0      0      0
#
#                  Ticket      Fare    Cabin Embarked  summation
# 75               348123    7.6500    F G73        S          0
# 134          C.A. 29178   13.0000      NaN        S          0
# 246              347071    7.7750      NaN        S          0
# 267              347083    7.7750      NaN        S          1
# 271                LINE    0.0000      NaN        S          0
# 343              244361   13.0000      NaN        S          0
# 353              349237   17.8000      NaN        S          1
# 370               11765   55.4417      E50        C          1
# 442              347076    7.7750      NaN        S          1
# 484               11967   91.0792      B49        C          1
# 498              113781  151.5500  C22 C26        S          3
# 580              237789   30.0000      NaN        S          2
# 666              234686   13.0000      NaN        S          0
# 685       SC/Paris 2123   41.5792      NaN        C          3
# 693                2672    7.2250      NaN        C          0
# 703               36864    7.7417      NaN        Q          0
# 728              236853   26.0000      NaN        S          1
# 729    STON/O2. 3101271    7.9250      NaN        S          1
# 784  SOTON/O.Q. 3101312    7.0500      NaN        S          0
# 785              374887    7.2500      NaN        S          0
# 794              349203    7.8958      NaN        S          0
# 880              230433   26.0000      NaN        S          1
# 884     SOTON/OQ 392076    7.0500      NaN        S          0

# %%
len(df[df["Age"]==25])
# Out:
# 23

# %%
#9 . how many person died whose age was less then 40

# %%
df[df["Age"]<=40]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)    1  39.0      0
# 886                              Montvila, Rev. Juozas    0  27.0      0
# 887                       Graham, Miss. Margaret Edith    1  19.0      0
# 889                              Behr, Mr. Karl Howell    0  26.0      0
# 890                                Dooley, Mr. Patrick    0  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  summation
# 0        0         A/5 21171   7.2500   NaN        S          1
# 1        0          PC 17599  71.2833   C85        C          1
# 2        0  STON/O2. 3101282   7.9250   NaN        S          0
# 3        0            113803  53.1000  C123        S          1
# 4        0            373450   8.0500   NaN        S          0
# ..     ...               ...      ...   ...      ...        ...
# 885      5            382652  29.1250   NaN        Q          5
# 886      0            211536  13.0000   NaN        S          0
# 887      0            112053  30.0000   B42        S          0
# 889      0            111369  30.0000  C148        C          0
# 890      0            370376   7.7500   NaN        Q          0
#
# [564 rows x 13 columns]

# %%
#10 . from a  cabin column seperate text and numeric value .
df["Cabin"]
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  summation    891 non-null    int64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 90.6+ KB

# %%
type(df["Cabin"])
# Out:
# pandas.core.series.Series

# %%
df.dropna(inplace = True)

# %%
split_data = df["Cabin"].str.split("t")

# %%
split_data
# Out:
# 1              [C85]
# 3             [C123]
# 6              [E46]
# 10              [G6]
# 11            [C103]
#            ...
# 871            [D35]
# 872    [B51 B53 B55]
# 879            [C50]
# 887            [B42]
# 889           [C148]
# Name: Cabin, Length: 183, dtype: object

# %%
#2nd Dataset

# %%
import pandas as pd
pd.read_csv(r"D:\Personal\DATA SCIENEC STUFF\iNeuron Doc\PANDAS FILES\bank\bank.csv")
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
pd.read_csv(r"D:\Personal\DATA SCIENEC STUFF\iNeuron Doc\PANDAS FILES\bank\bank.csv",sep=";")
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 0     cellular   19   oct        79         1     -1         0  unknown  no
# 1     cellular   11   may       220         1    339         4  failure  no
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [4521 rows x 17 columns]

# %%
df2=pd.read_csv(r"D:\Personal\DATA SCIENEC STUFF\iNeuron Doc\PANDAS FILES\bank\bank.csv",sep=";")

# %%
#1 . how many campaign available in this dataset .

# %%
df2["campaign"]
# Out:
# 0        1
# 1        1
# 2        1
# 3        4
# 4        1
#         ..
# 4516     5
# 4517     1
# 4518    11
# 4519     4
# 4520     2
# Name: campaign, Length: 4521, dtype: int64

# %%
len(df2["campaign"])
# Out:
# 4521

# %%
#2 . how many users do we have with housing and personal loan .

# %%
df2["loan"]
# Out:
# 0        no
# 1       yes
# 2        no
# 3       yes
# 4        no
#        ...
# 4516     no
# 4517    yes
# 4518     no
# 4519     no
# 4520    yes
# Name: loan, Length: 4521, dtype: object

# %%
df2["loan"].value_counts()
# Out:
# no     3830
# yes     691
# Name: loan, dtype: int64

# %%
df2["housing"].value_counts()
# Out:
# yes    2559
# no     1962
# Name: housing, dtype: int64

# %%
#3. how many person do we have whose age is 60+ . 
df2["age"]
# Out:
# 0       30
# 1       33
# 2       35
# 3       30
# 4       59
#         ..
# 4516    33
# 4517    57
# 4518    57
# 4519    28
# 4520    44
# Name: age, Length: 4521, dtype: int64

# %%
len(df2[df2["age"]>=60])
# Out:
# 174

# %%
#4 . in which month we have trageted most of the customer .

# %%
df2["month"]
# Out:
# 0       oct
# 1       may
# 2       apr
# 3       jun
# 4       may
#        ...
# 4516    jul
# 4517    may
# 4518    aug
# 4519    feb
# 4520    apr
# Name: month, Length: 4521, dtype: object

# %%
max(df2["month"])
# Out:
# 'sep'

# %%
#5 . which mode of call is giving you more result

# %%
df2["contact"]
# Out:
# 0       cellular
# 1       cellular
# 2       cellular
# 3        unknown
# 4        unknown
#           ...
# 4516    cellular
# 4517     unknown
# 4518    cellular
# 4519    cellular
# 4520    cellular
# Name: contact, Length: 4521, dtype: object

# %%
df2["contact"].value_counts()
# Out:
# cellular     2896
# unknown      1324
# telephone     301
# Name: contact, dtype: int64

# %%
#6 . how many enterpeures do we have in this list

# %%
df2["job"]
# Out:
# 0          unemployed
# 1            services
# 2          management
# 3          management
# 4         blue-collar
#             ...
# 4516         services
# 4517    self-employed
# 4518       technician
# 4519      blue-collar
# 4520     entrepreneur
# Name: job, Length: 4521, dtype: object

# %%
df2["job"].value_counts()
# Out:
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: job, dtype: int64

# %%
#7 . how many customers do we have with negative balance

# %%
df2["balance"]
# Out:
# 0       1787
# 1       4789
# 2       1350
# 3       1476
# 4          0
#         ...
# 4516    -333
# 4517   -3313
# 4518     295
# 4519    1137
# 4520    1136
# Name: balance, Length: 4521, dtype: int64

# %%
df2["balance"]
# Out:
# -3313

# %%
#8. prepare a group of data based on education level .

# %%
df2["education"]
# Out:
# 0         primary
# 1       secondary
# 2        tertiary
# 3        tertiary
# 4       secondary
#           ...
# 4516    secondary
# 4517     tertiary
# 4518    secondary
# 4519    secondary
# 4520     tertiary
# Name: education, Length: 4521, dtype: object

# %%
df2.groupby(["education"])

# %%
gp_edu=df2.groupby(["education"])
gp_edu.head()
# Out:
#      age            job   marital  education default  balance housing loan  \
# 0     30     unemployed   married    primary      no     1787      no   no
# 1     33       services   married  secondary      no     4789     yes  yes
# 2     35     management    single   tertiary      no     1350     yes   no
# 3     30     management   married   tertiary      no     1476     yes  yes
# 4     59    blue-collar   married  secondary      no        0     yes   no
# 5     35     management    single   tertiary      no      747      no   no
# 6     36  self-employed   married   tertiary      no      307     yes   no
# 7     39     technician   married  secondary      no      147     yes   no
# 8     41   entrepreneur   married   tertiary      no      221     yes   no
# 9     43       services   married    primary      no      -88     yes  yes
# 10    39       services   married  secondary      no     9374     yes   no
# 11    43         admin.   married  secondary      no      264     yes   no
# 18    25    blue-collar    single    primary      no     -221     yes   no
# 20    38     management  divorced    unknown      no        0     yes   no
# 26    55    blue-collar   married    primary      no      627     yes   no
# 27    67        retired   married    unknown      no      696      no   no
# 36    78        retired  divorced    primary      no      229      no   no
# 49    61         admin.   married    unknown      no     4629     yes   no
# 132   43    blue-collar   married    unknown     yes     -715     yes   no
# 133   48         admin.   married    unknown      no        0     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome    y
# 0     cellular   19   oct        79         1     -1         0  unknown   no
# 1     cellular   11   may       220         1    339         4  failure   no
# 2     cellular   16   apr       185         1    330         1  failure   no
# 3      unknown    3   jun       199         4     -1         0  unknown   no
# 4      unknown    5   may       226         1     -1         0  unknown   no
# 5     cellular   23   feb       141         2    176         3  failure   no
# 6     cellular   14   may       341         1    330         2    other   no
# 7     cellular    6   may       151         2     -1         0  unknown   no
# 8      unknown   14   may        57         2     -1         0  unknown   no
# 9     cellular   17   apr       313         1    147         2  failure   no
# 10     unknown   20   may       273         1     -1         0  unknown   no
# 11    cellular   17   apr       113         2     -1         0  unknown   no
# 18     unknown   23   may       250         1     -1         0  unknown   no
# 20    cellular   18   nov        96         2     -1         0  unknown   no
# 26     unknown    5   may       247         1     -1         0  unknown   no
# 27   telephone   17   aug       119         1    105         2  failure   no
# 36   telephone   22   oct        97         1     -1         0  unknown  yes
# 49    cellular   27   jan       181         1     92         1  success  yes
# 132    unknown   30   may        67         3     -1         0  unknown   no
# 133   cellular    8   may        85         1    168         2  failure   no
